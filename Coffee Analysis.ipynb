# %%
#Import Libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn import linear_model as lm
import seaborn as sns
import numpy as np
import scipy.stats as stats
from pathlib import Path

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = Path('Resources/merged_data_cleaned.csv')
coffee_df = pd.read_csv(csv_path)
coffee_df.head()
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0           0  Arabica                 metad plc          Ethiopia
# 1           1  Arabica                 metad plc          Ethiopia
# 2           2  Arabica  grounds for health admin         Guatemala
# 3           3  Arabica       yidnekachew dabessa          Ethiopia
# 4           4  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude  ...  Color  \
# 0      metad agricultural developmet plc      1950-2200  ...  Green
# 1      metad agricultural developmet plc      1950-2200  ...  Green
# 2                                    NaN  1600 - 1800 m  ...    NaN
# 3  yidnekachew debessa coffee plantation      1800-2200  ...  Green
# 4      metad agricultural developmet plc      1950-2200  ...  Green
#
#   Category.Two.Defects        Expiration                  Certification.Body  \
# 0                    0   April 3rd, 2016  METAD Agricultural Development plc
# 1                    1   April 3rd, 2016  METAD Agricultural Development plc
# 2                    0    May 31st, 2011        Specialty Coffee Association
# 3                    2  March 25th, 2016  METAD Agricultural Development plc
# 4                    2   April 3rd, 2016  METAD Agricultural Development plc
#
#                       Certification.Address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
# 2  36d0d00a3724338ba7937c52a378d085f2172daa
# 3  309fcf77415a3661ae83e027f7e5f05dad786e44
# 4  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       Certification.Contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#   altitude_low_meters altitude_high_meters altitude_mean_meters
# 0              1950.0               2200.0               2075.0
# 1              1950.0               2200.0               2075.0
# 2              1600.0               1800.0               1700.0
# 3              1800.0               2200.0               2000.0
# 4              1950.0               2200.0               2075.0
#
# [5 rows x 44 columns]

# %%
coffee_df.columns
# Out:
# Index(['Unnamed: 0', 'Species', 'Owner', 'Country.of.Origin', 'Farm.Name',
#        'Lot.Number', 'Mill', 'ICO.Number', 'Company', 'Altitude', 'Region',
#        'Producer', 'Number.of.Bags', 'Bag.Weight', 'In.Country.Partner',
#        'Harvest.Year', 'Grading.Date', 'Owner.1', 'Variety',
#        'Processing.Method', 'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body',
#        'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness', 'Cupper.Points',
#        'Total.Cup.Points', 'Moisture', 'Category.One.Defects', 'Quakers',
#        'Color', 'Category.Two.Defects', 'Expiration', 'Certification.Body',
#        'Certification.Address', 'Certification.Contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
coffee_df_new = coffee_df.rename(columns={'Total.Cup.Points': 'CoffeeScore',
                                            'Country.of.Origin': 'Country_of_Origin',
                                         'Processing.Method': 'Processing_Method'})

# %% [markdown]
# ## Data Cleaning

# %%
# Clean Country of Origin
coffee_df_new['Country_of_Origin'] = coffee_df_new['Country_of_Origin'].replace(['United States (Hawaii)'],
                                                                                'United States (HI)').replace(['United States (Puerto Rico)'],
                                                                                                              'United States (PR)').replace(['Tanzania, United Republic Of'], 'Tanzania')

# Clean Region
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['campos altos - cerrado',
                                                           'carmo de minas', 'high mogiana',
                                                           'mantiqueira de minas', 'minas gerais, br',
                                                           'mogiana', 'monte carmelo', 'mountains of minas gerais'],
                                                          'Minas Gerais').replace(['south of minas', 'sul de minas',
                                                                                   'sul de minas - carmo de minas'],
                                                                                  'Sul de Minas').replace(['alta paulista (sao paulo)'],
                                                                                                          'Alta Paulista').replace(['brazil matas de minas'],
                                                                                                                                   'matas de minas').replace(['cerrado - monte carmelo - minas gerais',
                                                                                                                                   'chapadÃ£o de ferro (cerrado mineiro)'],
                                                                                                                                   'cerrado').replace(['vale da grama'], 'grama valley')

coffee_df_new['Region'] = coffee_df_new['Region'].replace(['52 narino (exact location: mattituy; municipal region: florida code 381',
                                                           'nariÃ±o'], 'Narino').replace(['huila supremo', 'south huila'], 'huila')

coffee_df_new['Region'] = coffee_df_new['Region'].replace(['valle central'], 'central valley').replace(['west and central valley'], 'west valley')

coffee_df_new['Region'] = coffee_df_new['Region'].replace(['ataco, apaneca - ilamatepec mountain range',
                                                           'department of ahuachapan, municipality of apanecallamatepec mountain'],
                                                           'apaneca').replace(['el balsamo, quezaltepec'], 'Chalatenango')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['province of manabi, ecuador'], 'Manabi').replace(['san juan, playas'], 'San Juan')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['blida,kercha,guji,oromia',
                                                           'guji-hambela'], 'Guji').replace(['kefa zone, gimbo distict, at a place called woka araba, south west ethiopia.'],
                                                                                            'Keffa Zone').replace(['gedio',
                                                                                                                   'snnp/kaffa zone,gimbowereda',
                                                                                                                   'snnprg; kafa; telo woreda; shada kebele'], 'SNNPR').replace(['ethiopia, sidamo',
                                                                                                                   'sidamo'], 'Sidama').replace(['kelem welega', 'limu', 'oromiya'],
                                                                                                                                                'oromia').replace(['aricha'], 'yirgacheffe')

coffee_df_new['Region'] = coffee_df_new['Region'].replace(['chuva, san marcos', 
                                                           'el tumbador, san marcos',
                                                           'la reforma, san marcos'],
                                                          'san marcos').replace(['nuevo oriente', 'orient', 'oriente'],
                                                                                 'santa rosa').replace(['san lucas toliman, solola'],
                                                                                                       'solola').replace(['aldea xeucalvitz, ixil region, quiche department'],
                                                                                                                         'Quiche').replace(['sacatepequez, guatemala'],
                                                                                                                                           'Sacatepequez')

coffee_df_new['Region'] = coffee_df_new['Region'].replace(["department d'artibonite , haiti"],
                                                           'Artibonite').replace(['dondon, haiti'],
                                                                                 'Dondon').replace(['thiotte, haiti'], 'Thiotte')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['central region',
                                                           'comayagua, honduras', 'siguatepeque, comayagua'],
                                                          'comayagua').replace(['el paraÃ­so',
                                                                                'guinope el paraÃ­so'], 'El Paraiso').replace(['marcala'],
                                                                                                                              'La Paz').replace(['san marcos'], 'ocotepeque')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['chickmangalore', 'chikmagalur karnataka',
                                                           'chikmagalur karnataka india', 'chikmagalur karnataka indua'],
                                                          'chikmagalur') 
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['aceh gayo',
                                                           'aceh tengah'], 'aceh').replace(['lington nihuta',
                                                                                            'lintong', 'sumatra brastagi'],
                                                                                           'Sumatra').replace(['central kenya'],
                                                                                                              'Central').replace(['temanggung, indonesia'],
                                                                                                                                 'Central Java')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['lao p.d.r.'],
                                                          'Bolaven Plateau').replace(['paksong,laos'],
                                                                                     'Paksong').replace(['chamarel (south west)'],
                                                                                                        'Chamarel')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['los angeles'],
                                                          'Baja').replace(['amatenango de la frontera',
                                                                           'chiapas, jaltenango', 'chilÃ³n',
                                                                           'escuitla', 'jaltenango', 'la concordia',
                                                                           'la concordia, chiapas', 'motozintla',
                                                                           'motozintla, chiapas', 'ocosingo',
                                                                           'sacÃºn palma, municipio de chilÃ³n, chiapas',
                                                                           'san pedro cotzilnam', 'santa maria sitepec',
                                                                           'sierra fraylesca, chiapas', 'sierra norte yajalon, chiapas',
                                                                           'sierra, chiapas', 'siltepec el triunfo',
                                                                           'siltepec el triunfo, chiapas, mexico', 'tapachula',
                                                                           'tuxtla gutierrez', 'yajalon'],
                                                                          'chiapas').replace(['canoas', 'cofradia de suchitlan',
                                                                                              'el remudadero', 'la cumbre', 'manzanillo'], 'colima').replace(['cuarenteÃ±o'],
                                                                                              'El Cuarenteno').replace(['atoyac de alvarez', 'iliatenco, guerrero',
                                                                                                                        'zihuatanejo de azueta'],
                                                                                                                       'Guerrero').replace(['calnali, hidalgo',
                                                                                                                                            'chapulhuacan, hidalgo',
                                                                                                                                            'huazalingo, hidalgo', 'jaltocan, hidalgo',
                                                                                                                                            'san bartolo tutotepec', 'tenango de doria, hidalgo',
                                                                                                                                            'tlanchinol, hidalgo'], 'Hidalgo') 
                                                           
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['el desmoronado, talpan de allende jalisco',
                                                           'talpa de allende'], 'Jalisco').replace(['santo reyes nopala'],
                                                                                                   'juquila').replace(['adolfo lopez mateos',
                                                                                                                       'tepetzingo'], 'mexico').replace(['ohuapan, tlaltetela'],
                                                                                                                       'Michoacan').replace(['la yerba', 'la yerbabuena'],
                                                                                                                                            'nayarit')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['huautla de jimenez', 'pluma hidalogo, oaxaca',
                                                           'san miguel del puerto', 'santa catarina juquila',
                                                           'santo domingo cacalotepec', 'sierra alta mixe y zapoteca',
                                                           'temaxcalapa', 'villa talea de castro', 'xochitonalco, huautla',
                                                           'zaragoza itundujia'], 'oaxaca').replace(['tlacuilotepec', 'tlatlauquitepec',
                                                                                                     'xicotepec de juarez',
                                                                                                     'zapotitlan de mendez'], 'Puebla').replace(['san fernando'], 'Tamaulipas')  
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['altotonga', 'chocaman, veracruz', 'coatepec', 'coatepec, coatepec',
                                                           'coscomatepec', 'fortÃ­n de las flores', 'hustusco', 'ixhuatlan del cafe',
                                                           'juchique de ferrer', 'mahuixtlan', 'progreso santa rosa teocelo', 'tepictla',
                                                           'totutla', 'xalapa', 'yecuatla', 'zentla'], 'Veracruz')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['doe kwin, pyin oo lwin', 'pyin oo lwin'],
                                                          'pyinoolwin').replace(['yauk sauk, shan state'],
                                                                                'South Shan State').replace(['ywar ngan township'],
                                                                                                            'ywar ngan').replace(['dipilto, nueva segovia'],
                                                                                                                                 'nueva segovia')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['chiayi alishan å˜‰ç¾©ç¸£é˜¿é‡Œå±±é„‰',
                                                           'chiayi fanluå˜‰ç¾©ç¸£ç•ªè·¯é„‰',
                                                           'leye, alishan township, chiayi county',
                                                           'leye, alishan township, chiayi county å˜‰ç¾©é˜¿é‡Œå±±æ¨‚é‡Žæ‘'],
                                                          'Chiayi').replace(['changhua baguashan å½°åŒ–å¸‚å…«å¦å±±'],
                                                                            'Changhua').replace(['yunlin é›²æž—ç¸£çŸ³å£',
                                                                                                 'yunlin gukeng he bao é›²æž—ç¸£å¤å‘é„‰è·è‹žæ‘'],
                                                                                                'Gukeng Township').replace(['åœ‹å§“é„‰ guoshing township'],\
                                                                                                                           'Guoshing Township').replace(['natou county'],
                                                                                                                           'nantou')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['taichung taiping å°ä¸­å¸‚å¤ªå¹³å€',
                                                           'taichung xinshe å°ä¸­å¸‚æ–°ç¤¾å€'],
                                                          'Taichung').replace(['å°å—å¸‚æ±å±±å€ (dongshan dist., tainan city)',
                                                                               'å°å—å¸‚æ±å±±å€( dongshan dist., tainan city)',
                                                                               'baihe dist., tainan city è‡ºå—å¸‚ç™½æ²³å€',
                                                                               'dongshan dist., tainan city å°å—å¸‚æ±å±±å€',
                                                                               'dongshan dist., tainan city è‡ºå—å¸‚æ±å±±å€',
                                                                               'nanxi dist., tainan city è‡ºå—å¸‚æ¥ è¥¿å€'],
                                                                              'Tainan City').replace(['å˜‰ç¾©é˜¿é‡Œå±±', 'å¤å‘é„‰è·åŒ…æ‘å°–å±±å‘60è™Ÿ',
                                                                                                      'å°ä¸­å’Œå¹³å€', 'å°ä¸­æ–°ç¤¾', 'å°æ±å¤ªéº»é‡Œ	å°ç£',
                                                                                                      'å—æŠ•åœ‹å§“', 'è‹—æ —ä¸‰ç£', 'è‹—æ —æ³°å®‰',
                                                                                                      'taiwu township , pingtung county å±æ±ç¸£æ³°æ­¦é„‰'], 'Taiwu Township')
                                                           
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['arusha meru'], 'arusha').replace(['luwero central region'],
                                                                                             'central').replace(['chiang rai thailand',
                                                                                                                 'chiangrai', 'doi chaang village, chiang rai, thialand',
                                                                                                                 'thailand'], 'chiang rai').replace(['bulambuli eastern region',
                                                                                                                                                     'eastern uganda',
                                                                                                                                                     'iganga namadrope eastern'],
                                                                                                                                                    'eastern').replace(['kapchorwa eastern'], 'kapchorwa')
                                                           
coffee_df_new['Region'] = coffee_df_new['Region'].replace(['karatu arusha',
                                                           'karatu ngorogoro', 'karatu northern',
                                                           'manyara, karatu'], 'Karatu').replace(['kasese, mt. rwenzori'],
                                                                                                 'kasese').replace(['iwala village, mbeya rural'],
                                                                                                                   'mbeya').replace(['sipi, mt elgon'],
                                                                                                                                    'mt elgon').replace(['ruvuma, mbinga'],
                                                                                                                                    'ruvuma').replace(['sheema south western'],
                                                                                                                                                      'south western')
                                                           
coffee_df_new.head(20)
#coffee_df_new.to_csv("Coffee_exp.csv", index=False)
# Out:
#     Unnamed: 0  Species                               Owner  \
# 0            0  Arabica                           metad plc
# 1            1  Arabica                           metad plc
# 2            2  Arabica            grounds for health admin
# 3            3  Arabica                 yidnekachew dabessa
# 4            4  Arabica                           metad plc
# 5            5  Arabica                           ji-ae ahn
# 6            6  Arabica                       hugo valdivia
# 7            7  Arabica         ethiopia commodity exchange
# 8            8  Arabica         ethiopia commodity exchange
# 9            9  Arabica              diamond enterprise plc
# 10          10  Arabica                       mohammed lalo
# 11          11  Arabica  cqi q coffee sample representative
# 12          12  Arabica  cqi q coffee sample representative
# 13          13  Arabica            grounds for health admin
# 14          14  Arabica         ethiopia commodity exchange
# 15          15  Arabica  cqi q coffee sample representative
# 16          16  Arabica            grounds for health admin
# 17          17  Arabica         ethiopia commodity exchange
# 18          18  Arabica              yunnan coffee exchange
# 19          19  Arabica                       essencecoffee
# 20          20  Arabica  cqi q coffee sample representative
# 21          21  Arabica              the coffee source inc.
# 22          22  Arabica               roberto licona franco
# 23          23  Arabica  cqi q coffee sample representative
# 24          24  Arabica                           ji-ae ahn
# 25          25  Arabica                            nucoffee
# 26          26  Arabica         ethiopia commodity exchange
# 27          27  Arabica               kabum trading company
# 28          28  Arabica                     bismarck castro
# 29          29  Arabica              lin, che-hao krude 林哲豪
# 30          30  Arabica                           nora zeas
# 31          31  Arabica              specialty coffee-korea
# 32          32  Arabica                            nucoffee
# 33          33  Arabica                    francisco a mena
# 34          34  Arabica                      hider abamecha
# 35          35  Arabica                         daniel magu
# 36          36  Arabica    kona pacific farmers cooperative
# 37          37  Arabica    kona pacific farmers cooperative
# 38          38  Arabica         ethiopia commodity exchange
# 39          39  Arabica  cqi q coffee sample representative
# 40          40  Arabica                  itdp international
# 41          41  Arabica            jacques pereira carneiro
# 42          42  Arabica            jacques pereira carneiro
# 43          43  Arabica              lin, che-hao krude 林哲豪
# 44          44  Arabica                       jungle estate
# 45          45  Arabica                            nucoffee
# 46          46  Arabica           great lakes coffee uganda
# 47          47  Arabica                           lusso lab
# 48          48  Arabica                           lusso lab
# 49          49  Arabica                                afca
#
#      Country_of_Origin                                 Farm.Name  \
# 0             Ethiopia                                 metad plc
# 1             Ethiopia                                 metad plc
# 2            Guatemala  san marcos barrancas "san cristobal cuch
# 3             Ethiopia     yidnekachew dabessa coffee plantation
# 4             Ethiopia                                 metad plc
# 5               Brazil                                       NaN
# 6                 Peru                                       NaN
# 7             Ethiopia                                     aolme
# 8             Ethiopia                                     aolme
# 9             Ethiopia                         tulla coffee farm
# 10            Ethiopia                   fahem coffee plantation
# 11       United States                                   el filo
# 12       United States                                los cedros
# 13  United States (HI)                             arianna farms
# 14            Ethiopia                                     aolme
# 15       United States                                 el águila
# 16           Indonesia                               toarco jaya
# 17            Ethiopia                                       NaN
# 18               China                               echo coffee
# 19            Ethiopia                                drima zede
# 20       United States                                  el rodeo
# 21          Costa Rica                                   several
# 22              Mexico                              la herradura
# 23       United States                                  la curva
# 24            Ethiopia                                       NaN
# 25              Brazil                           fazenda kaquend
# 26            Ethiopia                                       NaN
# 27              Uganda                chebonet (23) women coffee
# 28            Honduras                              los hicaques
# 29              Taiwan                  tsoustructive garden 鄒築園
# 30           Nicaragua                                       NaN
# 31            Tanzania                                       NaN
# 32              Brazil                           fazenda recreio
# 33          Costa Rica                    exclusive coffees s.a.
# 34            Ethiopia         haider abamecha coffee plantation
# 35               Kenya                                   kangunu
# 36  United States (HI)                                       NaN
# 37  United States (HI)          kona pacific farmers cooperative
# 38            Ethiopia  phone number | 0911-51-08-01, email | at
# 39       United States                              la primavera
# 40            Thailand                                 co-op #12
# 41              Brazil                     pereira estate coffee
# 42              Brazil                     pereira estate coffee
# 43              Taiwan             sunshine valley estate 向陽高山咖啡
# 44               Kenya                             jungle estate
# 45              Brazil                           fazenda kaquend
# 46              Uganda                                   kaasayi
# 47            Colombia                           ecobio colombia
# 48               Kenya                                  kianjavi
# 49              Uganda                                       NaN
#
#                            Lot.Number  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                          YNC-06114
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                102
# 29  Tsoustructive 2015 Sumatra Typica
# 30                                NaN
# 31                                NaN
# 32                                NaN
# 33                                NaN
# 34                                NaN
# 35                                NaN
# 36                                NaN
# 37                                NaN
# 38                                NaN
# 39                                NaN
# 40                                NaN
# 41                                NaN
# 42                                NaN
# 43                                NaN
# 44                                NaN
# 45                                NaN
# 46                                NaN
# 47                                NaN
# 48                                NaN
# 49                                NaN
#
#                                              Mill              ICO.Number  \
# 0                                       metad plc               2014/2015
# 1                                       metad plc               2014/2015
# 2                                             NaN                     NaN
# 3                                         wolensu                     NaN
# 4                                       metad plc               2014/2015
# 5                                             NaN                     NaN
# 6                                             hvc                     NaN
# 7                                         c.p.w.e                010/0338
# 8                                         c.p.w.e                010/0338
# 9                               tulla coffee farm                 2014/15
# 10                                            NaN                     NaN
# 11                                            NaN                 unknown
# 12                                            NaN                 unknown
# 13                                            NaN                     NaN
# 14                                        c.p.w.e                010/0338
# 15                                            NaN                 unknown
# 16                                            NaN                     NaN
# 17                                            NaN                010/0056
# 18                               echo coffee mill                     NaN
# 19                                     drima zede               100181006
# 20                                            NaN                 unknown
# 21                       cafe altura de san ramon              5-562-0015
# 22                                   la herradura                       0
# 23                                            NaN                 unknown
# 24                                            NaN                     NaN
# 25                                            NaN           002/1251/0073
# 26                                            NaN         010/0056/Sidamo
# 27                          kabum trading company                       0
# 28                             cigrah s.a de c.v.              13-111-053
# 29                       tsoustructive garden 鄒築園                  Taiwan
# 30                     beneficio atlantic condega                790-0013
# 31                                            NaN                 A019116
# 32                                            NaN           002/1251/0068
# 33                         exclusive coffees s.a,                 5818009
# 34  faysal abamecha processing plant at yebu town                 2014/15
# 35                     central kenya coffee mills                       0
# 36                                            NaN                  220452
# 37                                            NaN  HDOA 210128 Kona Fancy
# 38                                            NaN                010/0170
# 39                                            NaN                 unknown
# 40                                            NaN              01-011-512
# 41                                       cocarive           002/1352/0045
# 42                                       cocarive           002/1352/0045
# 43                  sunshine valley estate 向陽高山咖啡                  Taiwan
# 44                               nkg coffee mills                     NIL
# 45                                            NaN           002/1251/0071
# 46                             great lakes coffee                       0
# 47                                            NaN                    NONE
# 48                                            NaN                    NONE
# 49                                            NaN                       x
#
#                                   Company                       Altitude  ...  \
# 0       metad agricultural developmet plc                      1950-2200  ...
# 1       metad agricultural developmet plc                      1950-2200  ...
# 2                                     NaN                  1600 - 1800 m  ...
# 3   yidnekachew debessa coffee plantation                      1800-2200  ...
# 4       metad agricultural developmet plc                      1950-2200  ...
# 5                                     NaN                            NaN  ...
# 6   richmond investment-coffee department                            NaN  ...
# 7                                     NaN                      1570-1700  ...
# 8                                     NaN                      1570-1700  ...
# 9                  diamond enterprise plc                      1795-1850  ...
# 10                fahem coffee plantation                      1855-1955  ...
# 11               coffee quality institute  meters above sea level: 1.872  ...
# 12               coffee quality institute  meters above sea level: 1.943  ...
# 13                                    NaN                        2000 ft  ...
# 14                                    NaN                      1570-1700  ...
# 15               coffee quality institute  meters above sea level: 2.080  ...
# 16                                    NaN                     1200-1800m  ...
# 17                                    NaN                            NaN  ...
# 18                 yunnan coffee exchange                           1450  ...
# 19                         essence coffee                     1700-2000m  ...
# 20               coffee quality institute  meters above sea level: 2.019  ...
# 21                 the coffee source inc.                      1300 msnm  ...
# 22                                    NaN                           1320  ...
# 23               coffee quality institute  meters above sea level: 2.112  ...
# 24                                    NaN                            NaN  ...
# 25                               nucoffee                          1250m  ...
# 26                                    NaN                            NaN  ...
# 27                  kabum trading company                           1950  ...
# 28                      cigrah s.a de c.v                           1400  ...
# 29               taiwan coffee laboratory                           1200  ...
# 30                                    NaN                            NaN  ...
# 31                                    NaN                            NaN  ...
# 32                               nucoffee                           1300  ...
# 33                 exclusive coffees s.a.                           1300  ...
# 34          haider abamecha coffee export                      1750-1800  ...
# 35                           c dorman ltd                           1800  ...
# 36       kona pacific farmers cooperative                            NaN  ...
# 37                                    NaN                            NaN  ...
# 38                                    NaN                            NaN  ...
# 39               coffee quality institute  meters above sea level: 1.941  ...
# 40                             lanna cafe                           1300  ...
# 41                                    NaN                            1.2  ...
# 42                                    NaN                            1.2  ...
# 43               taiwan coffee laboratory                         1000 m  ...
# 44                       keremara limited                           1754  ...
# 45                               nucoffee                          1250m  ...
# 46                                   ucda                            NaN  ...
# 47                       lusso coffee lab                      900-1500m  ...
# 48                       lusso coffee lab                    1520m-2200m  ...
# 49                     kawacom uganda ltd                     1400-1900m  ...
#
#            Color Category.Two.Defects            Expiration  \
# 0          Green                    0       April 3rd, 2016
# 1          Green                    1       April 3rd, 2016
# 2            NaN                    0        May 31st, 2011
# 3          Green                    2      March 25th, 2016
# 4          Green                    2       April 3rd, 2016
# 5   Bluish-Green                    1   September 3rd, 2014
# 6   Bluish-Green                    0  September 17th, 2013
# 7            NaN                    0   September 2nd, 2011
# 8            NaN                    0   September 2nd, 2011
# 9          Green                    4      March 29th, 2016
# 10           NaN                    1      March 26th, 2016
# 11           NaN                    0      March 12th, 2016
# 12           NaN                    0      March 12th, 2016
# 13           NaN                    2        May 31st, 2011
# 14           NaN                    2     August 31st, 2011
# 15           NaN                    0      March 12th, 2016
# 16           NaN                    0        May 31st, 2011
# 17           NaN                    2       June 16th, 2011
# 18         Green                    0       April 7th, 2017
# 19           NaN                    8      March 24th, 2016
# 20          None                    0      March 12th, 2016
# 21         Green                    2       April 2nd, 2015
# 22         Green                    0       July 26th, 2013
# 23           NaN                    0      March 12th, 2016
# 24  Bluish-Green                    1   September 3rd, 2014
# 25         Green                    2    December 2nd, 2012
# 26           NaN                    2       June 16th, 2011
# 27         Green                    1       June 26th, 2015
# 28         Green                    3        May 18th, 2018
# 29         Green                    0        May 18th, 2017
# 30           NaN                    2        May 18th, 2011
# 31  Bluish-Green                    1   September 3rd, 2014
# 32         Green                    2    December 2nd, 2012
# 33    Blue-Green                    0    December 2nd, 2016
# 34         Green                    3      March 26th, 2016
# 35    Blue-Green                    1        May 30th, 2015
# 36           NaN                    4       April 6th, 2013
# 37           NaN                    1    January 28th, 2012
# 38           NaN                    2       June 17th, 2011
# 39           NaN                    0      March 12th, 2016
# 40         Green                    9      April 12th, 2013
# 41           NaN                    2     January 4th, 2012
# 42           NaN                    3     January 4th, 2012
# 43         Green                    0        June 9th, 2016
# 44  Bluish-Green                    2    January 29th, 2016
# 45    Blue-Green                    2    December 2nd, 2012
# 46           NaN                    0     October 1st, 2015
# 47         Green                    1      March 20th, 2015
# 48         Green                    1    February 6th, 2015
# 49    Blue-Green                    0   February 12th, 2013
#
#                             Certification.Body  \
# 0           METAD Agricultural Development plc
# 1           METAD Agricultural Development plc
# 2                 Specialty Coffee Association
# 3           METAD Agricultural Development plc
# 4           METAD Agricultural Development plc
# 5           Specialty Coffee Institute of Asia
# 6           Specialty Coffee Institute of Asia
# 7                  Ethiopia Commodity Exchange
# 8                  Ethiopia Commodity Exchange
# 9           METAD Agricultural Development plc
# 10          METAD Agricultural Development plc
# 11                                    Almacafé
# 12                                    Almacafé
# 13                Specialty Coffee Association
# 14                 Ethiopia Commodity Exchange
# 15                                    Almacafé
# 16                Specialty Coffee Association
# 17                 Ethiopia Commodity Exchange
# 18                      Yunnan Coffee Exchange
# 19                Blossom Valley International
# 20                                    Almacafé
# 21                Specialty Coffee Association
# 22                                     AMECAFE
# 23                                    Almacafé
# 24          Specialty Coffee Institute of Asia
# 25                                    NUCOFFEE
# 26                 Ethiopia Commodity Exchange
# 27         Uganda Coffee Development Authority
# 28                Instituto Hondureño del Café
# 29                Specialty Coffee Association
# 30                Specialty Coffee Association
# 31          Specialty Coffee Institute of Asia
# 32                                    NUCOFFEE
# 33  Specialty Coffee Association of Costa Rica
# 34          METAD Agricultural Development plc
# 35            Kenya Coffee Traders Association
# 36                Specialty Coffee Association
# 37                Specialty Coffee Association
# 38                 Ethiopia Commodity Exchange
# 39                                    Almacafé
# 40                Specialty Coffee Association
# 41                Specialty Coffee Association
# 42                Specialty Coffee Association
# 43                Specialty Coffee Association
# 44            Kenya Coffee Traders Association
# 45                                    NUCOFFEE
# 46         Uganda Coffee Development Authority
# 47                Specialty Coffee Association
# 48                Specialty Coffee Association
# 49              Africa Fine Coffee Association
#
#                        Certification.Address  \
# 0   309fcf77415a3661ae83e027f7e5f05dad786e44
# 1   309fcf77415a3661ae83e027f7e5f05dad786e44
# 2   36d0d00a3724338ba7937c52a378d085f2172daa
# 3   309fcf77415a3661ae83e027f7e5f05dad786e44
# 4   309fcf77415a3661ae83e027f7e5f05dad786e44
# 5   726e4891cf2c9a4848768bd34b668124d12c4224
# 6   726e4891cf2c9a4848768bd34b668124d12c4224
# 7   a176532400aebdc345cf3d870f84ed3ecab6249e
# 8   a176532400aebdc345cf3d870f84ed3ecab6249e
# 9   309fcf77415a3661ae83e027f7e5f05dad786e44
# 10  309fcf77415a3661ae83e027f7e5f05dad786e44
# 11  e493c36c2d076bf273064f7ac23ad562af257a25
# 12  e493c36c2d076bf273064f7ac23ad562af257a25
# 13  36d0d00a3724338ba7937c52a378d085f2172daa
# 14  a176532400aebdc345cf3d870f84ed3ecab6249e
# 15  e493c36c2d076bf273064f7ac23ad562af257a25
# 16  36d0d00a3724338ba7937c52a378d085f2172daa
# 17  a176532400aebdc345cf3d870f84ed3ecab6249e
# 18  683fa6014608fc10ff681b0435b0b2dbe6df988f
# 19  fc45352eee499d8470cf94c9827922fb745bf815
# 20  e493c36c2d076bf273064f7ac23ad562af257a25
# 21  36d0d00a3724338ba7937c52a378d085f2172daa
# 22  59e396ad6e22a1c22b248f958e1da2bd8af85272
# 23  e493c36c2d076bf273064f7ac23ad562af257a25
# 24  726e4891cf2c9a4848768bd34b668124d12c4224
# 25  567f200bcc17a90070cb952647bf88141ad9c80c
# 26  a176532400aebdc345cf3d870f84ed3ecab6249e
# 27  188fe373b511e21f614564bf86aa4774270d8e04
# 28  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 29  36d0d00a3724338ba7937c52a378d085f2172daa
# 30  36d0d00a3724338ba7937c52a378d085f2172daa
# 31  726e4891cf2c9a4848768bd34b668124d12c4224
# 32  567f200bcc17a90070cb952647bf88141ad9c80c
# 33  8e0b118f3cf3121ab27c5387deacdb7d4d2a60b1
# 34  309fcf77415a3661ae83e027f7e5f05dad786e44
# 35  ccba45b89d859740b749878be8c6d16fbdb96c2e
# 36  36d0d00a3724338ba7937c52a378d085f2172daa
# 37  36d0d00a3724338ba7937c52a378d085f2172daa
# 38  a176532400aebdc345cf3d870f84ed3ecab6249e
# 39  e493c36c2d076bf273064f7ac23ad562af257a25
# 40  36d0d00a3724338ba7937c52a378d085f2172daa
# 41  36d0d00a3724338ba7937c52a378d085f2172daa
# 42  36d0d00a3724338ba7937c52a378d085f2172daa
# 43  36d0d00a3724338ba7937c52a378d085f2172daa
# 44  ccba45b89d859740b749878be8c6d16fbdb96c2e
# 45  567f200bcc17a90070cb952647bf88141ad9c80c
# 46  188fe373b511e21f614564bf86aa4774270d8e04
# 47  36d0d00a3724338ba7937c52a378d085f2172daa
# 48  36d0d00a3724338ba7937c52a378d085f2172daa
# 49  073285c0d45e2f5539012d969937e529564fa6fe
#
#                        Certification.Contact unit_of_measurement  \
# 0   19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1   19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3   19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4   19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 5   b70da261fcc84831e3e9620c30a8701540abc200                   m
# 6   b70da261fcc84831e3e9620c30a8701540abc200                   m
# 7   61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 8   61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 9   19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 10  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 11  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 12  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 13  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                  ft
# 14  61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 15  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 16  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 17  61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 18  f6d87a6c04653c569d4911a66f89d5e30ce83b93                   m
# 19  de73fc9412358b523d3a641501e542f31d2668b0                   m
# 20  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 21  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 22  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 23  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 24  b70da261fcc84831e3e9620c30a8701540abc200                   m
# 25  aa2ff513ffb9c844462a1fb07c599bce7f3bb53d                   m
# 26  61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 27  b7614767a5343729bbde3a2777c60ce836aed928                   m
# 28  7f521ca403540f81ec99daec7da19c2788393880                   m
# 29  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 30  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 31  b70da261fcc84831e3e9620c30a8701540abc200                   m
# 32  aa2ff513ffb9c844462a1fb07c599bce7f3bb53d                   m
# 33  5eb2b7129d9714c43825e44dc3bca9423de209e9                   m
# 34  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 35  d752c909a015f3c76224b3c5cc520f8a67afda74                   m
# 36  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                  ft
# 37  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                  ft
# 38  61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b                   m
# 39  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 40  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 41  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 42  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 43  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 44  d752c909a015f3c76224b3c5cc520f8a67afda74                   m
# 45  aa2ff513ffb9c844462a1fb07c599bce7f3bb53d                   m
# 46  b7614767a5343729bbde3a2777c60ce836aed928                   m
# 47  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 48  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 49  c4ab13415cdd69376a93780c0166e7b1a10481ea                   m
#
#    altitude_low_meters altitude_high_meters altitude_mean_meters
# 0               1950.0               2200.0               2075.0
# 1               1950.0               2200.0               2075.0
# 2               1600.0               1800.0               1700.0
# 3               1800.0               2200.0               2000.0
# 4               1950.0               2200.0               2075.0
# 5                  NaN                  NaN                  NaN
# 6                  NaN                  NaN                  NaN
# 7               1570.0               1700.0               1635.0
# 8               1570.0               1700.0               1635.0
# 9               1795.0               1850.0               1822.5
# 10              1855.0               1955.0               1905.0
# 11              1872.0               1872.0               1872.0
# 12              1943.0               1943.0               1943.0
# 13               609.6                609.6                609.6
# 14              1570.0               1700.0               1635.0
# 15              2080.0               2080.0               2080.0
# 16              1200.0               1800.0               1500.0
# 17                 NaN                  NaN                  NaN
# 18              1450.0               1450.0               1450.0
# 19              1700.0               2000.0               1850.0
# 20              2019.0               2019.0               2019.0
# 21              1300.0               1300.0               1300.0
# 22              1320.0               1320.0               1320.0
# 23              2112.0               2112.0               2112.0
# 24                 NaN                  NaN                  NaN
# 25              1250.0               1250.0               1250.0
# 26                 NaN                  NaN                  NaN
# 27              1950.0               1950.0               1950.0
# 28              1400.0               1400.0               1400.0
# 29              1200.0               1200.0               1200.0
# 30                 NaN                  NaN                  NaN
# 31                 NaN                  NaN                  NaN
# 32              1300.0               1300.0               1300.0
# 33              1300.0               1300.0               1300.0
# 34              1750.0               1800.0               1775.0
# 35              1800.0               1800.0               1800.0
# 36                 NaN                  NaN                  NaN
# 37                 NaN                  NaN                  NaN
# 38                 NaN                  NaN                  NaN
# 39              1941.0               1941.0               1941.0
# 40              1300.0               1300.0               1300.0
# 41                12.0                 12.0                 12.0
# 42                12.0                 12.0                 12.0
# 43              1000.0               1000.0               1000.0
# 44              1754.0               1754.0               1754.0
# 45              1250.0               1250.0               1250.0
# 46                 NaN                  NaN                  NaN
# 47               900.0               1500.0               1200.0
# 48              1520.0               2200.0               1860.0
# 49              1400.0               1900.0               1650.0
#
# [50 rows x 44 columns]

# %%
# delete unnecessary column
del coffee_df_new['Lot.Number']
del coffee_df_new['Mill']
del coffee_df_new['ICO.Number']
del coffee_df_new['Company']
del coffee_df_new['Producer']
del coffee_df_new['In.Country.Partner']
del coffee_df_new['Certification.Body']
del coffee_df_new['Certification.Address']
del coffee_df_new['Certification.Contact']
del coffee_df_new['Owner.1']

coffee_df_new.head(20)
# Out:
#     Unnamed: 0  Species                               Owner  \
# 0            0  Arabica                           metad plc
# 1            1  Arabica                           metad plc
# 2            2  Arabica            grounds for health admin
# 3            3  Arabica                 yidnekachew dabessa
# 4            4  Arabica                           metad plc
# 5            5  Arabica                           ji-ae ahn
# 6            6  Arabica                       hugo valdivia
# 7            7  Arabica         ethiopia commodity exchange
# 8            8  Arabica         ethiopia commodity exchange
# 9            9  Arabica              diamond enterprise plc
# 10          10  Arabica                       mohammed lalo
# 11          11  Arabica  cqi q coffee sample representative
# 12          12  Arabica  cqi q coffee sample representative
# 13          13  Arabica            grounds for health admin
# 14          14  Arabica         ethiopia commodity exchange
# 15          15  Arabica  cqi q coffee sample representative
# 16          16  Arabica            grounds for health admin
# 17          17  Arabica         ethiopia commodity exchange
# 18          18  Arabica              yunnan coffee exchange
# 19          19  Arabica                       essencecoffee
# 20          20  Arabica  cqi q coffee sample representative
# 21          21  Arabica              the coffee source inc.
# 22          22  Arabica               roberto licona franco
# 23          23  Arabica  cqi q coffee sample representative
# 24          24  Arabica                           ji-ae ahn
# 25          25  Arabica                            nucoffee
# 26          26  Arabica         ethiopia commodity exchange
# 27          27  Arabica               kabum trading company
# 28          28  Arabica                     bismarck castro
# 29          29  Arabica              lin, che-hao krude 林哲豪
# 30          30  Arabica                           nora zeas
# 31          31  Arabica              specialty coffee-korea
# 32          32  Arabica                            nucoffee
# 33          33  Arabica                    francisco a mena
# 34          34  Arabica                      hider abamecha
# 35          35  Arabica                         daniel magu
# 36          36  Arabica    kona pacific farmers cooperative
# 37          37  Arabica    kona pacific farmers cooperative
# 38          38  Arabica         ethiopia commodity exchange
# 39          39  Arabica  cqi q coffee sample representative
# 40          40  Arabica                  itdp international
# 41          41  Arabica            jacques pereira carneiro
# 42          42  Arabica            jacques pereira carneiro
# 43          43  Arabica              lin, che-hao krude 林哲豪
# 44          44  Arabica                       jungle estate
# 45          45  Arabica                            nucoffee
# 46          46  Arabica           great lakes coffee uganda
# 47          47  Arabica                           lusso lab
# 48          48  Arabica                           lusso lab
# 49          49  Arabica                                afca
#
#      Country_of_Origin                                 Farm.Name  \
# 0             Ethiopia                                 metad plc
# 1             Ethiopia                                 metad plc
# 2            Guatemala  san marcos barrancas "san cristobal cuch
# 3             Ethiopia     yidnekachew dabessa coffee plantation
# 4             Ethiopia                                 metad plc
# 5               Brazil                                       NaN
# 6                 Peru                                       NaN
# 7             Ethiopia                                     aolme
# 8             Ethiopia                                     aolme
# 9             Ethiopia                         tulla coffee farm
# 10            Ethiopia                   fahem coffee plantation
# 11       United States                                   el filo
# 12       United States                                los cedros
# 13  United States (HI)                             arianna farms
# 14            Ethiopia                                     aolme
# 15       United States                                 el águila
# 16           Indonesia                               toarco jaya
# 17            Ethiopia                                       NaN
# 18               China                               echo coffee
# 19            Ethiopia                                drima zede
# 20       United States                                  el rodeo
# 21          Costa Rica                                   several
# 22              Mexico                              la herradura
# 23       United States                                  la curva
# 24            Ethiopia                                       NaN
# 25              Brazil                           fazenda kaquend
# 26            Ethiopia                                       NaN
# 27              Uganda                chebonet (23) women coffee
# 28            Honduras                              los hicaques
# 29              Taiwan                  tsoustructive garden 鄒築園
# 30           Nicaragua                                       NaN
# 31            Tanzania                                       NaN
# 32              Brazil                           fazenda recreio
# 33          Costa Rica                    exclusive coffees s.a.
# 34            Ethiopia         haider abamecha coffee plantation
# 35               Kenya                                   kangunu
# 36  United States (HI)                                       NaN
# 37  United States (HI)          kona pacific farmers cooperative
# 38            Ethiopia  phone number | 0911-51-08-01, email | at
# 39       United States                              la primavera
# 40            Thailand                                 co-op #12
# 41              Brazil                     pereira estate coffee
# 42              Brazil                     pereira estate coffee
# 43              Taiwan             sunshine valley estate 向陽高山咖啡
# 44               Kenya                             jungle estate
# 45              Brazil                           fazenda kaquend
# 46              Uganda                                   kaasayi
# 47            Colombia                           ecobio colombia
# 48               Kenya                                  kianjavi
# 49              Uganda                                       NaN
#
#                          Altitude        Region  Number.of.Bags Bag.Weight  \
# 0                       1950-2200          Guji             300      60 kg
# 1                       1950-2200          Guji             300      60 kg
# 2                   1600 - 1800 m           NaN               5          1
# 3                       1800-2200        oromia             320      60 kg
# 4                       1950-2200          Guji             300      60 kg
# 5                             NaN           NaN             100      30 kg
# 6                             NaN           NaN             100      69 kg
# 7                       1570-1700        oromia             300      60 kg
# 8                       1570-1700        oromia             300      60 kg
# 9                       1795-1850         SNNPR              50      60 kg
# 10                      1855-1955        oromia             300      60 kg
# 11  meters above sea level: 1.872     antioquia              10       1 kg
# 12  meters above sea level: 1.943     antioquia              10       1 kg
# 13                        2000 ft          kona               1          1
# 14                      1570-1700        oromia             300      60 kg
# 15  meters above sea level: 2.080     antioquia              10       1 kg
# 16                     1200-1800m      sulawesi               1   2 kg,lbs
# 17                            NaN   yirgacheffe             150          6
# 18                           1450        yunnan               3      60 kg
# 19                     1700-2000m         SNNPR             250      60 kg
# 20  meters above sea level: 2.019     antioquia              10       1 kg
# 21                      1300 msnm     san ramon             250      3 lbs
# 22                           1320      Veracruz              14       1 kg
# 23  meters above sea level: 2.112     antioquia              10       1 kg
# 24                            NaN        Sidama             100      60 kg
# 25                          1250m  Sul de Minas               3      60 kg
# 26                            NaN        Sidama             150          6
# 27                           1950     kapchorwa             100      60 kg
# 28                           1400     comayagua             275      69 kg
# 29                           1200        Chiayi              20      50 kg
# 30                            NaN           NaN             275          6
# 31                            NaN           NaN             100      60 kg
# 32                           1300  grama valley              29      60 kg
# 33                           1300   west valley             250      2 lbs
# 34                      1750-1800        oromia             320      60 kg
# 35                           1800       muranga             320       1 kg
# 36                            NaN          kona              10    100 lbs
# 37                            NaN          kona              25    100 lbs
# 38                            NaN   yirgacheffe             300          6
# 39  meters above sea level: 1.941     antioquia              10       1 kg
# 40                           1300    chiang rai              53       1 kg
# 41                            1.2  Sul de Minas             300      60 kg
# 42                            1.2  Sul de Minas             300      60 kg
# 43                         1000 m        nantou              10      15 kg
# 44                           1754         nyeri              12      60 kg
# 45                          1250m  Sul de Minas               7      60 kg
# 46                            NaN       eastern               1      60 kg
# 47                      900-1500m        tolima               1       2 kg
# 48                    1520m-2200m        kiambu               1       1 kg
# 49                     1400-1900m      mt elgon               1      60 kg
#
#               Harvest.Year  ... Moisture Category.One.Defects Quakers  \
# 0                     2014  ...     0.12                    0     0.0
# 1                     2014  ...     0.12                    0     0.0
# 2                      NaN  ...     0.00                    0     0.0
# 3                     2014  ...     0.11                    0     0.0
# 4                     2014  ...     0.12                    0     0.0
# 5                     2013  ...     0.11                    0     0.0
# 6                     2012  ...     0.11                    0     0.0
# 7               March 2010  ...     0.03                    0     0.0
# 8               March 2010  ...     0.03                    0     0.0
# 9                     2014  ...     0.10                    0     0.0
# 10                    2014  ...     0.10                    0     0.0
# 11                    2014  ...     0.00                    0     0.0
# 12                    2014  ...     0.00                    0     0.0
# 13  Sept 2009 - April 2010  ...     0.00                    0     0.0
# 14              March 2010  ...     0.05                    0     0.0
# 15                    2014  ...     0.00                    0     0.0
# 16              May-August  ...     0.03                    0     0.0
# 17               2009/2010  ...     0.05                    0     0.0
# 18                    2015  ...     0.10                    0     0.0
# 19                    2014  ...     0.00                    0     0.0
# 20                    2014  ...     0.00                    0     0.0
# 21                    2014  ...     0.11                    0     0.0
# 22                    2012  ...     0.13                    0     0.0
# 23                    2014  ...     0.00                    0     0.0
# 24                    2013  ...     0.11                    0     0.0
# 25                    2011  ...     0.12                    0     0.0
# 26               2009/2010  ...     0.05                    0     0.0
# 27                    2013  ...     0.12                    0     0.0
# 28                    2016  ...     0.10                    0     0.0
# 29                    2015  ...     0.00                    0     0.0
# 30                     NaN  ...     0.08                    0     0.0
# 31                    2012  ...     0.11                    0     0.0
# 32                    2011  ...     0.12                    0     0.0
# 33               2015/2016  ...     0.00                    0     0.0
# 34                    2014  ...     0.10                    0     0.0
# 35                    2013  ...     0.12                    0     0.0
# 36                    2012  ...     0.00                    1     0.0
# 37                    2010  ...     0.00                    2     0.0
# 38               2009/2010  ...     0.10                    0     0.0
# 39                    2014  ...     0.00                    0     0.0
# 40                    2012  ...     0.10                    1     0.0
# 41                    2010  ...     0.08                    0     0.0
# 42                    2010  ...     0.01                    0     0.0
# 43                    2015  ...     0.12                    0     0.0
# 44                    2014  ...     0.11                    0     0.0
# 45                    2011  ...     0.11                    0     0.0
# 46                    2014  ...     0.00                    0     0.0
# 47                    2013  ...     0.12                    1     0.0
# 48                    2013  ...     0.11                    0     0.0
# 49                    2012  ...     0.10                    0     0.0
#
#            Color  Category.Two.Defects            Expiration  \
# 0          Green                     0       April 3rd, 2016
# 1          Green                     1       April 3rd, 2016
# 2            NaN                     0        May 31st, 2011
# 3          Green                     2      March 25th, 2016
# 4          Green                     2       April 3rd, 2016
# 5   Bluish-Green                     1   September 3rd, 2014
# 6   Bluish-Green                     0  September 17th, 2013
# 7            NaN                     0   September 2nd, 2011
# 8            NaN                     0   September 2nd, 2011
# 9          Green                     4      March 29th, 2016
# 10           NaN                     1      March 26th, 2016
# 11           NaN                     0      March 12th, 2016
# 12           NaN                     0      March 12th, 2016
# 13           NaN                     2        May 31st, 2011
# 14           NaN                     2     August 31st, 2011
# 15           NaN                     0      March 12th, 2016
# 16           NaN                     0        May 31st, 2011
# 17           NaN                     2       June 16th, 2011
# 18         Green                     0       April 7th, 2017
# 19           NaN                     8      March 24th, 2016
# 20          None                     0      March 12th, 2016
# 21         Green                     2       April 2nd, 2015
# 22         Green                     0       July 26th, 2013
# 23           NaN                     0      March 12th, 2016
# 24  Bluish-Green                     1   September 3rd, 2014
# 25         Green                     2    December 2nd, 2012
# 26           NaN                     2       June 16th, 2011
# 27         Green                     1       June 26th, 2015
# 28         Green                     3        May 18th, 2018
# 29         Green                     0        May 18th, 2017
# 30           NaN                     2        May 18th, 2011
# 31  Bluish-Green                     1   September 3rd, 2014
# 32         Green                     2    December 2nd, 2012
# 33    Blue-Green                     0    December 2nd, 2016
# 34         Green                     3      March 26th, 2016
# 35    Blue-Green                     1        May 30th, 2015
# 36           NaN                     4       April 6th, 2013
# 37           NaN                     1    January 28th, 2012
# 38           NaN                     2       June 17th, 2011
# 39           NaN                     0      March 12th, 2016
# 40         Green                     9      April 12th, 2013
# 41           NaN                     2     January 4th, 2012
# 42           NaN                     3     January 4th, 2012
# 43         Green                     0        June 9th, 2016
# 44  Bluish-Green                     2    January 29th, 2016
# 45    Blue-Green                     2    December 2nd, 2012
# 46           NaN                     0     October 1st, 2015
# 47         Green                     1      March 20th, 2015
# 48         Green                     1    February 6th, 2015
# 49    Blue-Green                     0   February 12th, 2013
#
#     unit_of_measurement  altitude_low_meters  altitude_high_meters  \
# 0                     m               1950.0                2200.0
# 1                     m               1950.0                2200.0
# 2                     m               1600.0                1800.0
# 3                     m               1800.0                2200.0
# 4                     m               1950.0                2200.0
# 5                     m                  NaN                   NaN
# 6                     m                  NaN                   NaN
# 7                     m               1570.0                1700.0
# 8                     m               1570.0                1700.0
# 9                     m               1795.0                1850.0
# 10                    m               1855.0                1955.0
# 11                    m               1872.0                1872.0
# 12                    m               1943.0                1943.0
# 13                   ft                609.6                 609.6
# 14                    m               1570.0                1700.0
# 15                    m               2080.0                2080.0
# 16                    m               1200.0                1800.0
# 17                    m                  NaN                   NaN
# 18                    m               1450.0                1450.0
# 19                    m               1700.0                2000.0
# 20                    m               2019.0                2019.0
# 21                    m               1300.0                1300.0
# 22                    m               1320.0                1320.0
# 23                    m               2112.0                2112.0
# 24                    m                  NaN                   NaN
# 25                    m               1250.0                1250.0
# 26                    m                  NaN                   NaN
# 27                    m               1950.0                1950.0
# 28                    m               1400.0                1400.0
# 29                    m               1200.0                1200.0
# 30                    m                  NaN                   NaN
# 31                    m                  NaN                   NaN
# 32                    m               1300.0                1300.0
# 33                    m               1300.0                1300.0
# 34                    m               1750.0                1800.0
# 35                    m               1800.0                1800.0
# 36                   ft                  NaN                   NaN
# 37                   ft                  NaN                   NaN
# 38                    m                  NaN                   NaN
# 39                    m               1941.0                1941.0
# 40                    m               1300.0                1300.0
# 41                    m                 12.0                  12.0
# 42                    m                 12.0                  12.0
# 43                    m               1000.0                1000.0
# 44                    m               1754.0                1754.0
# 45                    m               1250.0                1250.0
# 46                    m                  NaN                   NaN
# 47                    m                900.0                1500.0
# 48                    m               1520.0                2200.0
# 49                    m               1400.0                1900.0
#
#     altitude_mean_meters
# 0                 2075.0
# 1                 2075.0
# 2                 1700.0
# 3                 2000.0
# 4                 2075.0
# 5                    NaN
# 6                    NaN
# 7                 1635.0
# 8                 1635.0
# 9                 1822.5
# 10                1905.0
# 11                1872.0
# 12                1943.0
# 13                 609.6
# 14                1635.0
# 15                2080.0
# 16                1500.0
# 17                   NaN
# 18                1450.0
# 19                1850.0
# 20                2019.0
# 21                1300.0
# 22                1320.0
# 23                2112.0
# 24                   NaN
# 25                1250.0
# 26                   NaN
# 27                1950.0
# 28                1400.0
# 29                1200.0
# 30                   NaN
# 31                   NaN
# 32                1300.0
# 33                1300.0
# 34                1775.0
# 35                1800.0
# 36                   NaN
# 37                   NaN
# 38                   NaN
# 39                1941.0
# 40                1300.0
# 41                  12.0
# 42                  12.0
# 43                1000.0
# 44                1754.0
# 45                1250.0
# 46                   NaN
# 47                1200.0
# 48                1860.0
# 49                1650.0
#
# [50 rows x 34 columns]

# %%
#Look at key metrics by species
#Coffee Score by Species
species_group = coffee_df_new.groupby('Species')
coffee_score_species_metrics = species_group.agg({"CoffeeScore": ["mean", "median", "var", "std", "sem"]})
coffee_score_species_metrics
# Out:
#         CoffeeScore
#                mean median        var       std      sem
# Species
# Arabica   82.115927   82.5  12.360573  3.515761  0.09710
# Robusta   80.868929   81.5   5.959617  2.441233  0.46135

# %%
#Given the high ariance in coffee scores, in particular among arabica variaties, we can use a box plot to show distribution of coffee scores

#Calculate upper and lower bounds, IQR and identify outliers

#Create boxplot
# plt.boxplot(coffee_df_new)
# plt.xticks([1, 2], ['Arabica', 'Robusta']) 
# plt.show()

# %%
#Flavor by Species
flavor_species_metrics = species_group.agg({"Flavor": ["mean", "median", "var", "std", "sem"]})
flavor_species_metrics
# Out:
#            Flavor
#              mean median       var       std       sem
# Species
# Arabica  7.518070   7.58  0.159983  0.399979  0.011047
# Robusta  7.630714   7.71  0.092207  0.303656  0.057386

# %%
#Aroma by Species
aroma_species_metrics = species_group.agg({"Aroma": ["mean", "median", "var", "std", "sem"]})
aroma_species_metrics
# Out:
#             Aroma
#              mean median       var       std       sem
# Species
# Arabica  7.563806   7.58  0.143388  0.378666  0.010458
# Robusta  7.702500   7.67  0.087708  0.296156  0.055968

# %%
#Aftertaste by Species
aftertaste_species_metrics = species_group.agg({"Aftertaste": ["mean", "median", "var", "std", "sem"]})
aftertaste_species_metrics
# Out:
#         Aftertaste
#               mean median       var       std       sem
# Species
# Arabica   7.397696   7.42  0.164121  0.405119  0.011189
# Robusta   7.559643   7.67  0.117285  0.342469  0.064721

# %%
#Look at key metrics by processing method
processing_method_group = coffee_df_new.groupby('Processing_Method')
coffee_score_pm_metrics = processing_method_group.agg({'CoffeeScore': ["mean", "median", "var", "std", "sem"]})
coffee_score_pm_metrics
# Out:
#                           CoffeeScore
#                                  mean  median        var       std       sem
# Processing_Method
# Natural / Dry               82.245039  82.750   8.003929  2.829122  0.176133
# Other                       81.278462  81.830  15.986422  3.998302  0.784132
# Pulped natural / honey      82.807857  82.665   2.846787  1.687243  0.450935
# Semi-washed / Semi-pulped   82.633571  82.500   3.121245  1.766705  0.236086
# Washed / Wet                81.967816  82.420   7.184830  2.680453  0.093892

# %%
# Generate a bar graph of coffee scores by processing method
# plt.bar(processing_method_group['Processing_Method'], processing_method_group['CoffeeScore'])
# plt.xlabel("Processing_Method")
# plt.ylabel("CoffeeScore")
# plt.show()

# %%
#GroupBy Species and Country of Origin
#Count coffees by country for each species
species_by_country = coffee_df_new.groupby(['Species'])['Country_of_Origin'].value_counts()
species_by_country

#Look at percentage of coffees by country
#count_of_species = coffee_df_new['Species'].value_counts()
#count_of_species
#species_percent_by_country = species_by_country / count_of_species 
#species_percent_by_country
# Out:
# Species  Country_of_Origin
# Arabica  Mexico                236
#          Colombia              183
#          Guatemala             181
#          Brazil                132
#          Taiwan                 75
#          United States (HI)     73
#          Honduras               53
#          Costa Rica             51
#          Ethiopia               44
#          Tanzania               40
#          Thailand               32
#          Nicaragua              26
#          Uganda                 26
#          Kenya                  25
#          El Salvador            21
#          Indonesia              20
#          China                  16
#          Malawi                 11
#          Peru                   10
#          Myanmar                 8
#          United States           8
#          Vietnam                 7
#          Haiti                   6
#          Philippines             5
#          Panama                  4
#          United States (PR)      4
#          Laos                    3
#          Burundi                 2
#          Cote d?Ivoire           1
#          Ecuador                 1
#          India                   1
#          Japan                   1
#          Mauritius               1
#          Papua New Guinea        1
#          Rwanda                  1
#          Zambia                  1
# Robusta  India                  13
#          Uganda                 10
#          Ecuador                 2
#          United States           2
#          Vietnam                 1
# Name: Country_of_Origin, dtype: int64

# %%
#plot bar chart
country_count_chart = country_count
country_count_chart_clean = country_count.plot(kind='bar', figsize=(6,8))

#set x and y axis
country_count_chart_clean.set_xlabel("Country of Origin")
country_count_chart_clean.set_ylabel("Number of Coffees")

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #plot bar chart
# ----> 2 country_count_chart = country_count
#       3 country_count_chart_clean = country_count.plot(kind='bar', figsize=(6,8))
#       5 #set x and y axis
#
# NameError: name 'country_count' is not defined
